# %%
pip install delta-spark==2.4.0

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from delta import *

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/TrabalhoPratico'

builder = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:2.4.0") \
    .enableHiveSupport() \

spark = spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
spark.sql(
    """
    CREATE DATABASE silver LOCATION 'hdfs://hdfs-nn:9000/TrabalhoPratico/silver/'
    """
)

# %%
spark.sql(
    """
    SHOW DATABASES
    """
).show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# |   silver|
# |  silver1|
# +---------+

# %%
spark.sql(
    """
    DROP TABLE IF EXISTS silver.GenderInequalityIndex_DeltaTable
    """
)

spark.sql(
    """
    CREATE EXTERNAL TABLE silver.GenderInequalityIndex_DeltaTable (
        ISO3 VARCHAR(3),
        Pais VARCHAR(20),
        Continente VARCHAR(20),
        Hemisferio VARCHAR(20),
        Desenvolvimento_Humano VARCHAR(15),
        UNDP_regioes VARCHAR(3),
        HDI_rank int,
        GII_rank int,
        Index_1990 double,
        Index_1991 double,
        Index_1992 double,
        Index_1993 double,
        Index_1994 double,
        Index_1995 double,
        Index_1996 double,
        Index_1997 double,
        Index_1998 double,
        Index_1999 double,
        Index_2000 double,
        Index_2001 double,
        Index_2002 double,
        Index_2003 double,
        Index_2004 double,
        Index_2005 double,
        Index_2006 double,
        Index_2007 double,
        Index_2008 double,
        Index_2009 double,
        Index_2010 double,
        Index_2011 double,
        Index_2012 double,
        Index_2013 double,
        Index_2014 double,
        Index_2015 double,
        Index_2016 double,
        Index_2017 double,
        Index_2018 double,
        Index_2019 double,
        Index_2020 double,
        Index_2021 double
    )
    USING DELTA
    LOCATION 'hdfs://hdfs-nn:9000/TrabalhoPratico/silver/GenderInequalityIndex_DeltaTable/'
    """
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    SELECT *
    FROM silver.GenderInequalityIndex_DeltaTable
    """
).show()
# Out:
# +----+----+----------+----------+----------------------+------------+--------+--------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
# |ISO3|Pais|Continente|Hemisferio|Desenvolvimento_Humano|UNDP_regioes|HDI_rank|GII_rank|Index_1990|Index_1991|Index_1992|Index_1993|Index_1994|Index_1995|Index_1996|Index_1997|Index_1998|Index_1999|Index_2000|Index_2001|Index_2002|Index_2003|Index_2004|Index_2005|Index_2006|Index_2007|Index_2008|Index_2009|Index_2010|Index_2011|Index_2012|Index_2013|Index_2014|Index_2015|Index_2016|Index_2017|Index_2018|Index_2019|Index_2020|Index_2021|
# +----+----+----------+----------+----------------------+------------+--------+--------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
# +----+----+----------+----------+----------------------+------------+--------+--------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+

# %%
spark.sql(
    """
    DESCRIBE FORMATTED silver.GenderInequalityIndex_DeltaTable
    """
).toPandas()
# Out:
#                         col_name  \
# 0                           ISO3
# 1                           Pais
# 2                     Continente
# 3                     Hemisferio
# 4         Desenvolvimento_Humano
# 5                   UNDP_regioes
# 6                       HDI_rank
# 7                       GII_rank
# 8                     Index_1990
# 9                     Index_1991
# 10                    Index_1992
# 11                    Index_1993
# 12                    Index_1994
# 13                    Index_1995
# 14                    Index_1996
# 15                    Index_1997
# 16                    Index_1998
# 17                    Index_1999
# 18                    Index_2000
# 19                    Index_2001
# 20                    Index_2002
# 21                    Index_2003
# 22                    Index_2004
# 23                    Index_2005
# 24                    Index_2006
# 25                    Index_2007
# 26                    Index_2008
# 27                    Index_2009
# 28                    Index_2010
# 29                    Index_2011
# 30                    Index_2012
# 31                    Index_2013
# 32                    Index_2014
# 33                    Index_2015
# 34                    Index_2016
# 35                    Index_2017
# 36                    Index_2018
# 37                    Index_2019
# 38                    Index_2020
# 39                    Index_2021
# 40
# 41  # Detailed Table Information
# 42                          Name
# 43                          Type
# 44                      Location
# 45                      Provider
# 46                         Owner
# 47              Table Properties
#
#                                             data_type comment
# 0                                              string    None
# 1                                              string    None
# 2                                              string    None
# 3                                              string    None
# 4                                              string    None
# 5                                              string    None
# 6                                                 int    None
# 7                                                 int    None
# 8                                              double    None
# 9                                              double    None
# 10                                             double    None
# 11                                             double    None
# 12                                             double    None
# 13                                             double    None
# 14                                             double    None
# 15                                             double    None
# 16                                             double    None
# 17                                             double    None
# 18                                             double    None
# 19                                             double    None
# 20                                             double    None
# 21                                             double    None
# 22                                             double    None
# 23                                             double    None
# 24                                             double    None
# 25                                             double    None
# 26                                             double    None
# 27                                             double    None
# 28                                             double    None
# 29                                             double    None
# 30                                             double    None
# 31                                             double    None
# 32                                             double    None
# 33                                             double    None
# 34                                             double    None
# 35                                             double    None
# 36                                             double    None
# 37                                             double    None
# 38                                             double    None
# 39                                             double    None
# 40
# 41
# 42  spark_catalog.silver.genderinequalityindex_del...
# 43                                           EXTERNAL
# 44  hdfs://hdfs-nn:9000/TrabalhoPratico/silver/Gen...
# 45                                              delta
# 46                                             jovyan
# 47  [delta.minReaderVersion=1,delta.minWriterVersi...

# %%
spark.stop()
